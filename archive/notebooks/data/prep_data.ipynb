# %%
from google.colab import drive, auth
drive.mount('/content/drive')
auth.authenticate_user()

# -m = parallel/multithreaded; copies the big h5 and all zips in one shot
# !gsutil -m cp \
  /content/drive/MyDrive/VQA_cache/vqa_images_336.h5 \
  /content/drive/MyDrive/VQA/*.zip \
  /content/drive/MyDrive/test2015.zip \
  gs://prashant-vqa/data/

# %%
# !gsutil -m cp -r \
  /content/drive/MyDrive/unfrozen_results_ViT_CLIP_RoBERTa/results \
  gs://prashant-vqa/data/
